# %% [markdown]
# <a href="https://colab.research.google.com/github/nicks165/Analysis-Tensorflow/blob/master/Weaviate_evaluation_cohere_wiki_english_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# https://weaviate.io/developers/weaviate/quickstart/

# %%
# !pip install weaviate-client cohere datasets
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: weaviate-client in /usr/local/lib/python3.10/dist-packages (3.19.2)
# Requirement already satisfied: cohere in /usr/local/lib/python3.10/dist-packages (4.6.0)
# Requirement already satisfied: datasets in /usr/local/lib/python3.10/dist-packages (2.12.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.59.0 in /usr/local/lib/python3.10/dist-packages (from weaviate-client) (4.65.0)
# Requirement already satisfied: validators<=0.21.0,>=0.18.2 in /usr/local/lib/python3.10/dist-packages (from weaviate-client) (0.20.0)
# Requirement already satisfied: authlib>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from weaviate-client) (1.2.0)
# Requirement already satisfied: requests<2.29.0,>=2.28.0 in /usr/local/lib/python3.10/dist-packages (from weaviate-client) (2.28.2)
# Requirement already satisfied: aiohttp<4.0,>=3.0 in /usr/local/lib/python3.10/dist-packages (from cohere) (3.8.4)
# Requirement already satisfied: backoff<3.0,>=2.0 in /usr/local/lib/python3.10/dist-packages (from cohere) (2.2.1)
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (9.0.0)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets) (3.2.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from datasets) (1.22.4)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.11.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.14.1)
# Requirement already satisfied: dill<0.3.7,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.3.6)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (1.5.3)
# Requirement already satisfied: fsspec[http]>=2021.11.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (2023.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (6.0)
# Requirement already satisfied: responses<0.19 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.18.0)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.10/dist-packages (from datasets) (0.70.14)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0,>=3.0->cohere) (1.3.1)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0,>=3.0->cohere) (1.9.2)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0,>=3.0->cohere) (4.0.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0,>=3.0->cohere) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0,>=3.0->cohere) (1.3.3)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0,>=3.0->cohere) (2.0.12)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0,>=3.0->cohere) (6.0.4)
# Requirement already satisfied: cryptography>=3.2 in /usr/local/lib/python3.10/dist-packages (from authlib>=1.1.0->weaviate-client) (40.0.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0.0,>=0.11.0->datasets) (3.12.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0.0,>=0.11.0->datasets) (4.5.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<2.29.0,>=2.28.0->weaviate-client) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<2.29.0,>=2.28.0->weaviate-client) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<2.29.0,>=2.28.0->weaviate-client) (1.26.15)
# Requirement already satisfied: decorator>=3.4.0 in /usr/local/lib/python3.10/dist-packages (from validators<=0.21.0,>=0.18.2->weaviate-client) (4.4.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2022.7.1)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.10/dist-packages (from cryptography>=3.2->authlib>=1.1.0->weaviate-client) (1.15.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->datasets) (1.16.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.12->cryptography>=3.2->authlib>=1.1.0->weaviate-client) (2.21)

# %% [markdown]
# Initiatize Weaviate

# %%
def instantiateWeaviateClient():
  #auth_config = weaviate.AuthApiKey(api_key="lhmyvvjHtlqdyB9NZO1v4KrbWurdiWqzBMbf")  # Replace w/ your Weaviate instance API key
  auth_config = weaviate.AuthApiKey(api_key="ODYjhwMLhyrzL3daMEx7PsKna3AtBDJZU98J")
  #auth_config = weaviate.AuthApiKey(api_key="lhmyvvjHtlqdyB9NZO1v4KrbWurdiWqzBMbf")
  # Instantiate the client with the auth config for API token
  client = weaviate.Client(
    url="https://osv1ykq1soaj5kb6lb1uq.gcp-d.weaviate.cloud",#mine"https://wiki-2m-cluster-908ycmws.weaviate.network",   # Replace w/ your endpoint
    auth_client_secret=auth_config
  )
  
  # Instantiate the client with the auth config for username and password
  #client = weaviate.Client(
  #   url="https://osv1ykq1soaj5kb6lb1uq.gcp-d.weaviate.cloud/",  # Replace w/ your endpoint
    #auth_client_secret=weaviate.AuthClientPassword(
    #    username = "nicks165@gmail.com",  # Replace w/ your WCS username
    #    password = "12qwaszxQW",   # Replace w/ your Weaviate password
    #)
  #)
  return client

# %% [markdown]
# Initialize index/collection (class in weaviate)

# %%
import time
import string
import random
import json
import weaviate
import cohere
import numpy

def initialize_class(client):
  # Class definition object. Weaviate's autoschema feature will infer properties when importing.
  class_obj = {
      "class": "wikipedia_articles",
      "vectorizer": "none",
      "vectorIndexConfig": {
          "distance": "cosine"
      }
  }

  client = instantiateWeaviateClient()
  #client.schema.delete_class(class_obj["class"])

  # Add the class to the schema
  #IMPORTANT = Only execute once per cloud account
  if(client.schema.exists(class_obj["class"])):
    print("Class exists")
  else:
    client.schema.create_class(class_obj)
  
  
  #client.schema.exists(class_obj["class"])
  return class_obj

# %% [markdown]
# Confirm shape and save the dataset to disk

# %% [markdown]
# Load embeddings and metadata into Weaviate -
#  1. Load in batch
#  2. After hitting a threshold, insert 1 object and measure time
#  3. Measure query performance for the same threshold

# %%
def upsert_one_record(client, co, class_obj): 
  # initializing size of string
  N = 7
 
  # using random.choices()
  # generating random strings
  randomString = ''.join(random.choices(string.ascii_uppercase +
                             string.digits, k=N))
  
  dataToupd = "This is a new record " + randomString

  newVector = {
      "vector": co.embed(texts=[dataToupd], model='multilingual-22-12').embeddings[0]
  }
  
  # Configure a batch process
  # create metadata dictionary
  properties = {
          "text": "New Data added " + dataToupd,
          }
  
  start_time = time.time() 
  #client.batch.add_data_object(properties, class_obj["class"], vector=newVector["vector"])

  data_uuid = client.data_object.create(
    properties,
    class_obj["class"],
    vector = newVector["vector"]
  )

  print("Updated with one Record (uuid: {0}) and Time taken --- {1} seconds ---".format(data_uuid, time.time() - start_time))

# %% [markdown]
# Querying the dataset

# %%
def issue_measure_query_time(client, co, class_obj):

  query1 = "What was the cause of the major recession in the early 20th century?"
  query2 = "Where is Mount Everest?"
  query3 = "something else"

  queries = [query1, query2, query3]

  timeTakenList = []

  ## Issue 3 queries and take the average

  for i in range(0, 2):
    # create the query embedding
    nearVector = {
        "vector": co.embed(texts=queries, model='multilingual-22-12').embeddings[i]
    }

    query_start_time = time.time()

    result = client.query.get(class_obj["class"], ["text"]).with_near_vector(nearVector).with_limit(2).with_additional(['certainty']).do()

    query_end_time = time.time()

    timeTakenList.append(query_end_time - query_start_time)

    #print(" For query number {0}, time taken for search = {1} ".format(queries[i], timeTakenList[i]))

   # print(json.dumps(result, indent=4))
  
  averageTimeTaken = numpy.average(timeTakenList)
  print("Average time taken for search = {0} ".format(averageTimeTaken))

# %% [markdown]
# conditional filtering on search query

# %%
def conditional_search(client, co, class_obj):
  
  query1 = "What was the cause of the major recession in the early 20th century?"
  query2 = "Where is Mount Everest?"
  query3 = "something else"

  queries = [query1, query2, query3]

  timeTakenList = []

  ## Issue 3 queries and take the average

  for i in range(0, 2):
    # create the query embedding
    nearVector = {
        "vector": co.embed(texts=queries, model='multilingual-22-12').embeddings[i]
    }

    query_start_time = time.time()

    result = (client.query
              .get(class_obj["class"], ["text"])
              .with_near_vector(nearVector)
              .with_where({
                "path": ["text"],
                "operator": "Like",
                "valueText": "recession"
                })
              .with_limit(2)
              .with_additional(['certainty'])
              .do())

    query_end_time = time.time()

    timeTakenList.append(query_end_time - query_start_time)

    #print(" For query number {0}, time taken for conditional search = {1} ".format(queries[i], timeTakenList[i]))

    #print(json.dumps(result, indent=4))
  
  averageTimeTaken = numpy.average(timeTakenList)
  print("Average time taken for conditional search = {0} ".format(averageTimeTaken))

# %%
import time
import uuid
MAX_ENTRIES = 35000000

def upsert_db_measure(docs, doc_embeddings, client, batch_size, total_inserted, workload_start_time, class_obj, previous_run_time):
  
  co = cohere.Client(f"o7lTEJeC1QHjU5I4Ee6U2I0m6l5wCOUPWqwoGM7H")  # Add your cohere API key from www.cohere.com
  client = instantiateWeaviateClient()

  # Configure a batch process, calls flush at the end of with block implicitly
  with client.batch as batch:
    batch.batch_size=batch_size
    start_time = time.time()
    
    # Batch import all Questions
    for i, doc in enumerate(docs):
      # create metadata dictionary
      properties = {
          "text": doc["text"],
      }
      
      client.batch.add_data_object(properties, class_obj["class"], vector=doc_embeddings[i])

  total_inserted += batch_size

  if(total_inserted in range(0, MAX_ENTRIES, 100000)):
    print("=======================================================================================================")
    total_time = (time.time() - workload_start_time) + previous_run_time
    print("For {0} entries, time taken for inserts = {1} ".format(total_inserted, total_time))
    upsert_one_record(client, co, class_obj)
    issue_measure_query_time(client, co, class_obj)
    conditional_search(client, co, class_obj)

  return total_inserted

# %% [markdown]
# Load datset and get the embeddings from Cohere dataset at Huggingface

# %%
from datasets import load_dataset
import torch
import cohere

# Create a generator that yields chunks of the dataset
def chunk_generator(dataset, chunk_size, starting_index):
  for i in range(starting_index, len(dataset), chunk_size):
    yield dataset[i:i + chunk_size]

def load_cohere_dataset():
   # bring dataset to disk in Arrow table format
  dataset = load_dataset(f"Cohere/wikipedia-22-12-en-embeddings", split="train")
  return dataset

def load_execute_workload(client, class_obj, dataset):

  limit = -1 # keep -1 for all, else update to a positive number to limit

  chunk_size = 1000 # size of batch upserts and items kept in memory

  max_docs_loaded = 0

  #if the runs fails, we want to re-start and for the subsequent time measurements to be valid. Use this variable
  # paste the runtime for previous starting_index or set it to 0 otherwise
  previous_run_time = 83986.52872550391 # set to 0 when starting from scratch
  previous_docs_loaded = 20900000 # set to 0 when starting from scratch
  max_docs_loaded = previous_docs_loaded

  start_time = time.time()
  docs = []
  doc_embeddings = []
  # Iterate over the chunks
  for chunk in chunk_generator(dataset, chunk_size, previous_docs_loaded):
    for i in range(0, chunk_size):
      docs.append({"text" : chunk["text"][i]})
      doc_embeddings.append(chunk['emb'][i])

    max_docs_loaded = upsert_db_measure(docs, doc_embeddings, client, chunk_size, max_docs_loaded, start_time, class_obj, previous_run_time)
    
    # clear the lists because we want to re-use them for the next chunk
    docs.clear()
    doc_embeddings.clear()
    
    if (limit > 0 and max_docs_loaded >= limit):
      break
  
  total_time = (time.time() - start_time) + previous_run_time
  print ("succesfully executed workload for {0} entries with total time {1}"
    .format(max_docs_loaded, total_time))

# %% [markdown]
# Loading a big dataset is expensive. Seperate this step so that executing and debugging the main functions would be simple

# %%
dataset = load_cohere_dataset()
# Out:
# WARNING:datasets.builder:Found cached dataset parquet (/root/.cache/huggingface/datasets/Cohere___parquet/Cohere--wikipedia-22-12-en-embeddings-735980cfcb568494/0.0.0/2a3b91fbd88a2c90d1dbbb32b460cf621d31bd5b05b934492fdef7d8d6f236ec)

# %% [markdown]
# Seperating from main execution.

# %%
#client = instantiateWeaviateClient()
#class_obj = initialize_class(client)

# %%
client = instantiateWeaviateClient()
class_obj = initialize_class(client)
#download dataset and execute workload
load_execute_workload(client, class_obj, dataset)
# Out:
# =======================================================================================================
# For 21000000 entries, time taken for inserts = 84356.31703483962
# Updated with one Record (uuid: c012eff8-cc34-4322-9418-1007562a8a65) and Time taken --- 0.053124189376831055 seconds ---
# Average time taken for search = 0.04690539836883545
# Average time taken for conditional search = 0.20094096660614014
# =======================================================================================================
# For 21100000 entries, time taken for inserts = 84745.77724277877
# Updated with one Record (uuid: 87b9c017-4e8a-4a77-bb5a-999bc019f5db) and Time taken --- 0.04594993591308594 seconds ---
# Average time taken for search = 0.04642748832702637
# Average time taken for conditional search = 0.5257706642150879
# =======================================================================================================
# For 21200000 entries, time taken for inserts = 85139.85465133094
# Updated with one Record (uuid: 444bd471-0cc9-4f01-b39a-9fbd021a7d3b) and Time taken --- 0.04813790321350098 seconds ---
# Average time taken for search = 0.047870755195617676
# Average time taken for conditional search = 0.3728811740875244
# =======================================================================================================
# For 21300000 entries, time taken for inserts = 85527.83308517837
# Updated with one Record (uuid: b7d1ec21-66ec-423d-a0d8-6d0550b1b1c5) and Time taken --- 0.04701805114746094 seconds ---
# Average time taken for search = 0.048075079917907715
# Average time taken for conditional search = 0.2494971752166748
# =======================================================================================================
# For 21400000 entries, time taken for inserts = 85931.74083173179
# Updated with one Record (uuid: c4031290-2240-4c7b-89dd-e1e7013815ce) and Time taken --- 0.053292274475097656 seconds ---
# Average time taken for search = 0.048902034759521484
# Average time taken for conditional search = 0.5013121366500854
# =======================================================================================================
# For 21500000 entries, time taken for inserts = 86321.18374287986
# Updated with one Record (uuid: 86d10dca-3c42-4fdd-ae9b-6bc8435f8371) and Time taken --- 0.050194740295410156 seconds ---
# Average time taken for search = 0.04860234260559082
# Average time taken for conditional search = 0.42153143882751465
# =======================================================================================================
# For 21600000 entries, time taken for inserts = 86717.8413997879
# Updated with one Record (uuid: c41cbf04-068c-4bc8-9001-df259e1468e2) and Time taken --- 0.04612898826599121 seconds ---
# Average time taken for search = 0.05024445056915283
# Average time taken for conditional search = 0.27676403522491455
# =======================================================================================================
# For 21700000 entries, time taken for inserts = 87113.34192359351
# Updated with one Record (uuid: 1881180a-3158-4821-bf23-17336f17f8c2) and Time taken --- 0.05233430862426758 seconds ---
# Average time taken for search = 0.049944400787353516
# Average time taken for conditional search = 0.09251093864440918
# =======================================================================================================
# For 21800000 entries, time taken for inserts = 87511.2673517456
# Updated with one Record (uuid: 629392bf-376b-4655-ab6c-83cacdf593f1) and Time taken --- 0.05148005485534668 seconds ---
# Average time taken for search = 0.04945087432861328
# Average time taken for conditional search = 0.42008137702941895
# =======================================================================================================
# For 21900000 entries, time taken for inserts = 87915.65307962798
# Updated with one Record (uuid: 64f5deca-f269-497c-b707-eaeddd7e4b44) and Time taken --- 0.05048108100891113 seconds ---
# Average time taken for search = 0.04826855659484863
# Average time taken for conditional search = 0.4006667137145996
# =======================================================================================================
# For 22000000 entries, time taken for inserts = 88318.56231152915
# Updated with one Record (uuid: 60a71f0e-b397-469e-a238-ddc454f94d96) and Time taken --- 0.07320547103881836 seconds ---
# Average time taken for search = 0.05091392993927002
# Average time taken for conditional search = 0.15732884407043457
# =======================================================================================================
# For 22100000 entries, time taken for inserts = 88727.39501297378
# Updated with one Record (uuid: b79e7450-ee75-4de6-8ba0-12b96a29f253) and Time taken --- 0.05270218849182129 seconds ---
# Average time taken for search = 0.048995375633239746
# Average time taken for conditional search = 0.47594594955444336
# =======================================================================================================
# For 22200000 entries, time taken for inserts = 89128.98842656516
# Updated with one Record (uuid: b46c2bd4-8f9f-4012-84a5-c0c9542ee419) and Time taken --- 0.0480654239654541 seconds ---
# Average time taken for search = 0.048635005950927734
# Average time taken for conditional search = 0.3382890224456787
# =======================================================================================================
# For 22300000 entries, time taken for inserts = 89545.4117110958
# Updated with one Record (uuid: 694e7cba-66e2-4eab-bf6e-ac89c3f2e1ee) and Time taken --- 0.05100274085998535 seconds ---
# Average time taken for search = 0.047760605812072754
# Average time taken for conditional search = 0.16748106479644775
# =======================================================================================================
# For 22400000 entries, time taken for inserts = 89945.33812200927
# Updated with one Record (uuid: 7f9806a2-dec3-4a4c-92a0-ab06b90f0984) and Time taken --- 0.04992413520812988 seconds ---
# Average time taken for search = 0.0506516695022583
# Average time taken for conditional search = 0.450206995010376
# =======================================================================================================
# For 22500000 entries, time taken for inserts = 90355.00907266044
# Updated with one Record (uuid: dd371ac5-c805-49fd-96f1-0ca5ff36a5c4) and Time taken --- 0.04741549491882324 seconds ---
# Average time taken for search = 0.04746437072753906
# Average time taken for conditional search = 0.3682180643081665
# =======================================================================================================
# For 22600000 entries, time taken for inserts = 90769.4234734764
# Updated with one Record (uuid: 9d53ae45-b1cb-4b50-a4c5-ab0190cfff82) and Time taken --- 0.05081605911254883 seconds ---
# Average time taken for search = 0.05079364776611328
# Average time taken for conditional search = 0.19847404956817627
# =======================================================================================================
# For 22700000 entries, time taken for inserts = 91176.53558552169
# Updated with one Record (uuid: 099c96bf-9ce7-4667-b06c-858bfc244353) and Time taken --- 0.04218721389770508 seconds ---
# Average time taken for search = 0.04858541488647461
# Average time taken for conditional search = 0.48486340045928955
# =======================================================================================================
# For 22800000 entries, time taken for inserts = 91596.57970201873
# Updated with one Record (uuid: a3d6c71f-5ce3-4393-9a60-76fb8b2bd378) and Time taken --- 0.039604902267456055 seconds ---
# Average time taken for search = 0.051135897636413574
# Average time taken for conditional search = 0.3666543960571289
# =======================================================================================================
# For 22900000 entries, time taken for inserts = 92004.2220693817
# Updated with one Record (uuid: 4e0bfe27-d793-4b22-8d61-13c0e2c82499) and Time taken --- 0.04967379570007324 seconds ---
# Average time taken for search = 0.04866504669189453
# Average time taken for conditional search = 0.21896874904632568
# =======================================================================================================
# For 23000000 entries, time taken for inserts = 92409.66686022186
# Updated with one Record (uuid: 5bf67dee-1fe7-4815-ae2d-fe6afaf6fee6) and Time taken --- 0.047945499420166016 seconds ---
# Average time taken for search = 0.04947710037231445
# Average time taken for conditional search = 0.4847170114517212
# =======================================================================================================
# For 23100000 entries, time taken for inserts = 92828.36801803016
# Updated with one Record (uuid: e509adeb-f1e5-442a-8c6f-a2e6e2b3e066) and Time taken --- 0.05039238929748535 seconds ---
# Average time taken for search = 0.05002880096435547
# Average time taken for conditional search = 0.3584785461425781
# =======================================================================================================
# For 23200000 entries, time taken for inserts = 93235.39363443755
# Updated with one Record (uuid: ab8f712c-f5aa-42b4-95ba-e01d16312efa) and Time taken --- 0.04883861541748047 seconds ---
# Average time taken for search = 0.048949480056762695
# Average time taken for conditional search = 0.2388439178466797
# =======================================================================================================
# For 23300000 entries, time taken for inserts = 93656.01085436248
# Updated with one Record (uuid: 7376fa95-55d7-4fe7-9e8e-e5163587f523) and Time taken --- 0.04673576354980469 seconds ---
# Average time taken for search = 0.04814887046813965
# Average time taken for conditional search = 0.50145423412323
# =======================================================================================================
# For 23400000 entries, time taken for inserts = 94064.67604100608
# Updated with one Record (uuid: fdde370d-042f-4476-b2c3-918ae8193503) and Time taken --- 0.04722762107849121 seconds ---
# Average time taken for search = 0.04914975166320801
# Average time taken for conditional search = 0.36165285110473633
# =======================================================================================================
# For 23500000 entries, time taken for inserts = 94479.89421784782
# Updated with one Record (uuid: 2aa46d43-6b5b-4855-968f-fb85590f8f1b) and Time taken --- 0.050907135009765625 seconds ---
# Average time taken for search = 0.05018973350524902
# Average time taken for conditional search = 0.20122826099395752
# =======================================================================================================
# For 23600000 entries, time taken for inserts = 94897.71787655258
# Updated with one Record (uuid: d7e22d44-d40d-4e48-b1e9-6cfbc1991b91) and Time taken --- 0.05081367492675781 seconds ---
# Average time taken for search = 0.04956710338592529
# Average time taken for conditional search = 0.4817941188812256
# =======================================================================================================
# For 23700000 entries, time taken for inserts = 95310.81612956428
# Updated with one Record (uuid: 12e49b77-e3b2-4bb8-acb2-3a7516faddda) and Time taken --- 0.05146288871765137 seconds ---
# Average time taken for search = 0.04979121685028076
# Average time taken for conditional search = 0.3454573154449463
# =======================================================================================================
# For 23800000 entries, time taken for inserts = 95726.17552506828
# Updated with one Record (uuid: f2561cbe-2cd4-4956-8936-07c9ecfbcf66) and Time taken --- 0.04893231391906738 seconds ---
# Average time taken for search = 0.0480879545211792
# Average time taken for conditional search = 0.16683447360992432
# =======================================================================================================
# For 23900000 entries, time taken for inserts = 96138.80331313514
# Updated with one Record (uuid: e78fa0c0-2068-43fd-88f2-358d2c0d90c4) and Time taken --- 0.04750418663024902 seconds ---
# Average time taken for search = 0.049337029457092285
# Average time taken for conditional search = 0.43005824089050293
# =======================================================================================================
# For 24000000 entries, time taken for inserts = 96548.7095960369
# Updated with one Record (uuid: 4eeed5e7-6984-41ad-8320-88025050d950) and Time taken --- 0.050812721252441406 seconds ---
# Average time taken for search = 0.05046868324279785
# Average time taken for conditional search = 0.3271092176437378
# =======================================================================================================
# For 24100000 entries, time taken for inserts = 96971.13885247611
# Updated with one Record (uuid: dbeaf340-8703-4e20-ad01-45db84b3c62a) and Time taken --- 0.05487656593322754 seconds ---
# Average time taken for search = 0.05573320388793945
# Average time taken for conditional search = 0.14573132991790771
# =======================================================================================================
# For 24200000 entries, time taken for inserts = 97397.12221038245
# Updated with one Record (uuid: 72297e32-b7f8-4d8d-ac66-707d1cbfa0c8) and Time taken --- 0.05190324783325195 seconds ---
# Average time taken for search = 0.05034744739532471
# Average time taken for conditional search = 0.470872163772583
# =======================================================================================================
# For 24300000 entries, time taken for inserts = 97812.98432218932
# Updated with one Record (uuid: 7fb6ab98-f957-4b64-9b9d-b11ceb9bbcb0) and Time taken --- 0.051053762435913086 seconds ---
# Average time taken for search = 0.05058467388153076
# Average time taken for conditional search = 0.2930539846420288
# =======================================================================================================
# For 24400000 entries, time taken for inserts = 98221.84860741996
# Updated with one Record (uuid: 29e45747-aa91-4306-89c0-a7d96a33d966) and Time taken --- 0.04962611198425293 seconds ---
# Average time taken for search = 0.04942488670349121
# Average time taken for conditional search = 0.1259615421295166
# =======================================================================================================
# For 24500000 entries, time taken for inserts = 98637.98925387763
# Updated with one Record (uuid: a8ae6460-5b92-4909-80b1-a0b6adf8cbf7) and Time taken --- 0.046309471130371094 seconds ---
# Average time taken for search = 0.04988133907318115
# Average time taken for conditional search = 0.440616250038147
# =======================================================================================================
# For 24600000 entries, time taken for inserts = 99063.26050078773
# Updated with one Record (uuid: e7223998-40d9-4f90-afe5-a0f396d45cfe) and Time taken --- 0.05303549766540527 seconds ---
# Average time taken for search = 0.04735422134399414
# Average time taken for conditional search = 0.2851301431655884
# =======================================================================================================
# For 24700000 entries, time taken for inserts = 99486.58293735885
# Updated with one Record (uuid: 4aa71576-2b3f-44be-955f-fce4555c135a) and Time taken --- 0.04794144630432129 seconds ---
# Average time taken for search = 0.045697808265686035
# Average time taken for conditional search = 0.5170538425445557
# =======================================================================================================
# For 24800000 entries, time taken for inserts = 99913.0660117855
# Updated with one Record (uuid: 853f5346-bc50-4cf1-990b-5885938d63fd) and Time taken --- 0.05541181564331055 seconds ---
# Average time taken for search = 0.04942488670349121
# Average time taken for conditional search = 0.4092174768447876
# =======================================================================================================
# For 24900000 entries, time taken for inserts = 100327.93767225646
# Updated with one Record (uuid: 584d8bb6-5145-41bc-a7f9-09822bc5bc24) and Time taken --- 0.04790806770324707 seconds ---
# Average time taken for search = 0.05328238010406494
# Average time taken for conditional search = 0.2681492567062378
# =======================================================================================================
# For 25000000 entries, time taken for inserts = 100745.7326472988
# Updated with one Record (uuid: e34e98ae-baee-491c-8dd7-54f5cfb0156f) and Time taken --- 0.05078887939453125 seconds ---
# Average time taken for search = 0.0517122745513916
# Average time taken for conditional search = 0.5310311317443848
# =======================================================================================================
# For 25100000 entries, time taken for inserts = 101170.98709094428
# Updated with one Record (uuid: 5e235e85-03ba-426d-a9f5-93933cc37113) and Time taken --- 0.051714181900024414 seconds ---
# Average time taken for search = 0.04954349994659424
# Average time taken for conditional search = 0.30107903480529785
# =======================================================================================================
# For 25200000 entries, time taken for inserts = 101579.45179045104
# Updated with one Record (uuid: 4e73f831-13c5-49d0-b857-44bf99c683c6) and Time taken --- 0.04945111274719238 seconds ---
# Average time taken for search = 0.04913759231567383
# Average time taken for conditional search = 0.09556317329406738
# =======================================================================================================
# For 25300000 entries, time taken for inserts = 101990.77716696166
# Updated with one Record (uuid: 0ab26911-41a7-4c3c-b1b4-056cefd9af3d) and Time taken --- 0.048753976821899414 seconds ---
# Average time taken for search = 0.04939770698547363
# Average time taken for conditional search = 0.41879522800445557
# =======================================================================================================
# For 25400000 entries, time taken for inserts = 102410.3695944538
# Updated with one Record (uuid: 416324b4-da6a-45c9-b6d4-7a638002658b) and Time taken --- 0.051029205322265625 seconds ---
# Average time taken for search = 0.05081212520599365
# Average time taken for conditional search = 0.27616775035858154
# =======================================================================================================
# For 25500000 entries, time taken for inserts = 102831.66200768852
# Updated with one Record (uuid: bef6b95b-cd02-4931-ab06-ecd1ccc6bdf6) and Time taken --- 0.0509495735168457 seconds ---
# Average time taken for search = 0.05020439624786377
# Average time taken for conditional search = 0.5404959917068481
# =======================================================================================================
# For 25600000 entries, time taken for inserts = 103252.68744408988
# Updated with one Record (uuid: 34c9aabe-faef-4f19-bac3-401f474317c7) and Time taken --- 0.04989290237426758 seconds ---
# Average time taken for search = 0.04676496982574463
# Average time taken for conditional search = 0.3836519718170166
# =======================================================================================================
# For 25700000 entries, time taken for inserts = 103672.11372291946
# Updated with one Record (uuid: 83ac032b-d990-494c-9a83-13dd6354050a) and Time taken --- 0.04710650444030762 seconds ---
# Average time taken for search = 0.04889070987701416
# Average time taken for conditional search = 0.228019118309021
# =======================================================================================================
# For 25800000 entries, time taken for inserts = 104090.60360729598
# Updated with one Record (uuid: f676b3a7-5d64-4518-910c-f0d93b13f068) and Time taken --- 0.05191612243652344 seconds ---
# Average time taken for search = 0.05468785762786865
# Average time taken for conditional search = 0.5587130784988403
# =======================================================================================================
# For 25900000 entries, time taken for inserts = 104531.6031981697
# Updated with one Record (uuid: 8f6cb3a7-9ada-4046-9e33-29a81efae886) and Time taken --- 0.04800295829772949 seconds ---
# Average time taken for search = 0.06625139713287354
# Average time taken for conditional search = 0.38216543197631836
# =======================================================================================================
# For 26000000 entries, time taken for inserts = 104971.00266301536
# Updated with one Record (uuid: 801ac9e3-0707-49f3-a482-2bf9e70a38bd) and Time taken --- 0.051015377044677734 seconds ---
# Average time taken for search = 0.06934463977813721
# Average time taken for conditional search = 0.1793752908706665
# =======================================================================================================
# For 26100000 entries, time taken for inserts = 105400.46626317405
# Updated with one Record (uuid: 6756ce6a-a0fd-446d-acbe-8efdbf325ef1) and Time taken --- 0.05103349685668945 seconds ---
# Average time taken for search = 0.05031538009643555
# Average time taken for conditional search = 0.4450169801712036
# =======================================================================================================
# For 26200000 entries, time taken for inserts = 105836.18153941535
# Updated with one Record (uuid: 0856265a-0c94-49d6-b8f1-e08cf0ed1881) and Time taken --- 0.05519437789916992 seconds ---
# Average time taken for search = 0.05180799961090088
# Average time taken for conditional search = 0.4044574499130249
# =======================================================================================================
# For 26300000 entries, time taken for inserts = 106264.43412887954
# Updated with one Record (uuid: 24807b99-083d-4c0f-8615-564b1e8734ee) and Time taken --- 0.05157923698425293 seconds ---
# Average time taken for search = 0.051522016525268555
# Average time taken for conditional search = 0.5344806909561157
# =======================================================================================================
# For 26400000 entries, time taken for inserts = 106687.78526770973
# Updated with one Record (uuid: 902a4d9b-3cc8-441b-8f14-7a4694d89cd7) and Time taken --- 0.04963374137878418 seconds ---
# Average time taken for search = 0.0496823787689209
# Average time taken for conditional search = 0.37653279304504395
# =======================================================================================================
# For 26500000 entries, time taken for inserts = 107110.41787660026
# Updated with one Record (uuid: 7ee94529-e383-47e7-90c4-ae8dadae9208) and Time taken --- 0.048633575439453125 seconds ---
# Average time taken for search = 0.07067370414733887
# Average time taken for conditional search = 0.2524350881576538
# =======================================================================================================
# For 26600000 entries, time taken for inserts = 107528.18248879813
# Updated with one Record (uuid: bf9fc917-3c7c-4fd5-8430-8903cc074d95) and Time taken --- 0.04873776435852051 seconds ---
# Average time taken for search = 0.04920327663421631
# Average time taken for conditional search = 0.47474098205566406
# =======================================================================================================
# For 26700000 entries, time taken for inserts = 107948.16722953224
# Updated with one Record (uuid: 52051728-7f6e-4dd4-a2e7-3979c7e7214e) and Time taken --- 0.0456087589263916 seconds ---
# Average time taken for search = 0.07039928436279297
# Average time taken for conditional search = 0.33574604988098145
# =======================================================================================================
# For 26800000 entries, time taken for inserts = 108386.88663756751
# Updated with one Record (uuid: 83b6ebd3-1c7f-4d82-957a-5da06c893429) and Time taken --- 0.04801058769226074 seconds ---
# Average time taken for search = 0.044130921363830566
# Average time taken for conditional search = 0.07796013355255127
# =======================================================================================================
# For 26900000 entries, time taken for inserts = 108797.45820176505
# Updated with one Record (uuid: e1c985e6-ddb5-4fe1-9860-394bf54cda21) and Time taken --- 0.046915292739868164 seconds ---
# Average time taken for search = 0.048212409019470215
# Average time taken for conditional search = 0.4109841585159302
# =======================================================================================================
# For 27000000 entries, time taken for inserts = 109220.58276903533
# Updated with one Record (uuid: e0eb97b5-be07-4115-9d2d-3327be279f8b) and Time taken --- 0.04964733123779297 seconds ---
# Average time taken for search = 0.048861145973205566
# Average time taken for conditional search = 0.24090003967285156
# =======================================================================================================
# For 27100000 entries, time taken for inserts = 109633.48356950187
# Updated with one Record (uuid: 3a686f79-cb55-4b41-adf2-cf0f64dda258) and Time taken --- 0.046575069427490234 seconds ---
# Average time taken for search = 0.04957616329193115
# Average time taken for conditional search = 0.4991116523742676
# =======================================================================================================
# For 27200000 entries, time taken for inserts = 110060.39833867454
# Updated with one Record (uuid: 52557567-e633-4ae2-b7df-e5db4df07f07) and Time taken --- 0.048838138580322266 seconds ---
# Average time taken for search = 0.05033671855926514
# Average time taken for conditional search = 0.3430999517440796
# =======================================================================================================
# For 27300000 entries, time taken for inserts = 110510.04077088737
# Updated with one Record (uuid: 8a4ff984-4e84-40f5-b70a-381f1d02754d) and Time taken --- 0.04854249954223633 seconds ---
# Average time taken for search = 0.07140660285949707
# Average time taken for conditional search = 0.12990498542785645
# =======================================================================================================
# For 27400000 entries, time taken for inserts = 110935.9749490013
# Updated with one Record (uuid: 22dd4fd0-e5ce-4d89-b2e3-6a267329f503) and Time taken --- 0.052008867263793945 seconds ---
# Average time taken for search = 0.06962883472442627
# Average time taken for conditional search = 0.4801981449127197
# =======================================================================================================
# For 27500000 entries, time taken for inserts = 111360.57116448783
# Updated with one Record (uuid: 21accbdd-acd7-4ec5-9362-d798cf3fbc57) and Time taken --- 0.04954099655151367 seconds ---
# Average time taken for search = 0.048809051513671875
# Average time taken for conditional search = 0.24288403987884521
# =======================================================================================================
# For 27600000 entries, time taken for inserts = 111780.92883026504
# Updated with one Record (uuid: 90b41b11-f963-4cd6-903f-68882afe83cd) and Time taken --- 0.04247546195983887 seconds ---
# Average time taken for search = 0.04766237735748291
# Average time taken for conditional search = 0.4993267059326172
# =======================================================================================================
# For 27700000 entries, time taken for inserts = 112210.62173139953
# Updated with one Record (uuid: 1dedf969-b8e4-41ef-8bdb-ecaa26cda3e6) and Time taken --- 0.04609203338623047 seconds ---
# Average time taken for search = 0.04908561706542969
# Average time taken for conditional search = 0.32300400733947754
# =======================================================================================================
# For 27800000 entries, time taken for inserts = 112627.0368663063
# Updated with one Record (uuid: a7bf0f88-64b6-4ff6-8815-931b59f3e006) and Time taken --- 0.04770922660827637 seconds ---
# Average time taken for search = 0.049455881118774414
# Average time taken for conditional search = 0.04590117931365967
# =======================================================================================================
# For 27900000 entries, time taken for inserts = 113053.8314481964
# Updated with one Record (uuid: 10de212d-eccd-420e-b2a9-40704965d1ca) and Time taken --- 0.04309272766113281 seconds ---
# Average time taken for search = 0.049944519996643066
# Average time taken for conditional search = 0.3829522132873535
# =======================================================================================================
# For 28000000 entries, time taken for inserts = 113481.29544532203
# Updated with one Record (uuid: cf15f81e-cdbf-4cf7-a84b-d0fa9f4833ce) and Time taken --- 0.048403263092041016 seconds ---
# Average time taken for search = 0.049068450927734375
# Average time taken for conditional search = 0.20118916034698486
# =======================================================================================================
# For 28100000 entries, time taken for inserts = 113929.14561831855
# Updated with one Record (uuid: a493c74c-75d8-436e-9bf6-3cd0e153d830) and Time taken --- 0.04542350769042969 seconds ---
# Average time taken for search = 0.08239758014678955
# Average time taken for conditional search = 0.5009579658508301
# =======================================================================================================
# For 28200000 entries, time taken for inserts = 114360.42835533523
# Updated with one Record (uuid: 2c4adc9c-9c89-4912-a097-42d8e29b2698) and Time taken --- 0.04802656173706055 seconds ---
# Average time taken for search = 0.06491971015930176
# Average time taken for conditional search = 0.28065717220306396
# =======================================================================================================
# For 28300000 entries, time taken for inserts = 114793.30104958915
# Updated with one Record (uuid: d6c0e2c6-f5ed-4a32-83b6-174ae196307b) and Time taken --- 0.04882073402404785 seconds ---
# Average time taken for search = 0.05259442329406738
# Average time taken for conditional search = 0.49557363986968994
# =======================================================================================================
# For 28400000 entries, time taken for inserts = 115237.47507250213
# Updated with one Record (uuid: 2ecd2b4b-c787-4fee-a9d5-08ddddf896c8) and Time taken --- 0.050933837890625 seconds ---
# Average time taken for search = 0.05343937873840332
# Average time taken for conditional search = 0.372236967086792
# =======================================================================================================
# For 28500000 entries, time taken for inserts = 115665.63679468536
# Updated with one Record (uuid: 8dfbcc83-bc93-432d-bc5b-72235409515d) and Time taken --- 0.0487971305847168 seconds ---
# Average time taken for search = 0.05370604991912842
# Average time taken for conditional search = 0.1843547821044922
# =======================================================================================================
# For 28600000 entries, time taken for inserts = 116103.85038411521
# Updated with one Record (uuid: be9b0b94-bd31-4702-a5e9-1393e2d29ca4) and Time taken --- 0.04993391036987305 seconds ---
# Average time taken for search = 0.07310545444488525
# Average time taken for conditional search = 0.5102612972259521
# =======================================================================================================
# For 28700000 entries, time taken for inserts = 116529.14956223869
# Updated with one Record (uuid: 9acb159d-6fcc-4062-8f0e-e6f0ee407bd7) and Time taken --- 0.04923367500305176 seconds ---
# Average time taken for search = 0.05243837833404541
# Average time taken for conditional search = 1.0187734365463257
# =======================================================================================================
# For 28800000 entries, time taken for inserts = 116991.07123863601
# Updated with one Record (uuid: 820ca466-a4d8-4c81-9b8b-6489616699d1) and Time taken --- 0.04426240921020508 seconds ---
# Average time taken for search = 0.054650068283081055
# Average time taken for conditional search = 0.5325390100479126
# =======================================================================================================
# For 28900000 entries, time taken for inserts = 117445.46066701316
# Updated with one Record (uuid: 2e3f71be-a6d4-4cd0-8539-4c3aa7966646) and Time taken --- 0.055846214294433594 seconds ---
# Average time taken for search = 0.05117511749267578
# Average time taken for conditional search = 0.2960852384567261
# =======================================================================================================
# For 29000000 entries, time taken for inserts = 117879.85701382064
# Updated with one Record (uuid: 11d6233e-dcd3-4836-9e4d-b296fd3915a0) and Time taken --- 0.04867243766784668 seconds ---
# Average time taken for search = 0.0517200231552124
# Average time taken for conditional search = 0.528497576713562
# =======================================================================================================
# For 29100000 entries, time taken for inserts = 118316.80102956199
# Updated with one Record (uuid: 7b314a8e-a81c-4e4d-aac7-d407e50ca68c) and Time taken --- 0.04825592041015625 seconds ---
# Average time taken for search = 0.049530982971191406
# Average time taken for conditional search = 0.38404250144958496
# =======================================================================================================
# For 29200000 entries, time taken for inserts = 118762.0187031021
# Updated with one Record (uuid: db3f498f-4cb5-4dbb-9a91-505af277c474) and Time taken --- 0.04822254180908203 seconds ---
# Average time taken for search = 0.044019222259521484
# Average time taken for conditional search = 0.5683377981185913
# =======================================================================================================
# For 29300000 entries, time taken for inserts = 119196.961499094
# Updated with one Record (uuid: db27888b-c0b6-4565-9af9-ece63d2d8a9c) and Time taken --- 0.046237945556640625 seconds ---
# Average time taken for search = 0.04735136032104492
# Average time taken for conditional search = 0.427243709564209
# =======================================================================================================
# For 29400000 entries, time taken for inserts = 119624.13997566604
# Updated with one Record (uuid: 9f5efe34-9df9-4c34-83a8-a2ecbba32907) and Time taken --- 0.04893922805786133 seconds ---
# Average time taken for search = 0.05265212059020996
# Average time taken for conditional search = 0.16819405555725098
# =======================================================================================================
# For 29500000 entries, time taken for inserts = 120074.95752680206
# Updated with one Record (uuid: 0c8ca52d-9ef3-470f-8941-c0fcaf65c4f2) and Time taken --- 0.0473484992980957 seconds ---
# Average time taken for search = 0.07463419437408447
# Average time taken for conditional search = 0.442163348197937
# =======================================================================================================
# For 29600000 entries, time taken for inserts = 120523.92321908378
# Updated with one Record (uuid: e4077d69-c588-4b53-85aa-5443d6f9db97) and Time taken --- 0.04734086990356445 seconds ---
# Average time taken for search = 0.07265007495880127
# Average time taken for conditional search = 0.2541193962097168
# =======================================================================================================
# For 29700000 entries, time taken for inserts = 120976.1701754322
# Updated with one Record (uuid: 0da46c63-e968-4443-850a-a1e6eadb6136) and Time taken --- 0.04754805564880371 seconds ---
# Average time taken for search = 0.05216860771179199
# Average time taken for conditional search = 0.44212043285369873
# =======================================================================================================
# For 29800000 entries, time taken for inserts = 121424.08542573356
# Updated with one Record (uuid: ad1c7997-af69-4b84-8821-e703f4fc9b7d) and Time taken --- 0.04948782920837402 seconds ---
# Average time taken for search = 0.05221426486968994
# Average time taken for conditional search = 0.24638855457305908
# =======================================================================================================
# For 29900000 entries, time taken for inserts = 121876.5319501152
# Updated with one Record (uuid: c5380552-9a05-4f3f-9a85-0c9749d1b7c2) and Time taken --- 0.04772639274597168 seconds ---
# Average time taken for search = 0.04916179180145264
# Average time taken for conditional search = 0.4925422668457031
# =======================================================================================================
# For 30000000 entries, time taken for inserts = 122302.5796362152
# Updated with one Record (uuid: 20dfe62d-388d-4a4b-97dc-3ab4b01e9575) and Time taken --- 0.053208351135253906 seconds ---
# Average time taken for search = 0.050360798835754395
# Average time taken for conditional search = 0.29247045516967773
# =======================================================================================================
# For 30100000 entries, time taken for inserts = 122735.75599324607
# Updated with one Record (uuid: afeae3e3-51de-4bb3-ba6d-b9c169516374) and Time taken --- 0.07399439811706543 seconds ---
# Average time taken for search = 0.07390236854553223
# Average time taken for conditional search = 1.0218214988708496
# =======================================================================================================
# For 30200000 entries, time taken for inserts = 123185.45901691818
# Updated with one Record (uuid: d5ff6bb3-4cee-4446-bfd9-544818db2374) and Time taken --- 0.050615549087524414 seconds ---
# Average time taken for search = 0.06732344627380371
# Average time taken for conditional search = 0.3229646682739258
# =======================================================================================================
# For 30300000 entries, time taken for inserts = 123615.79176247024
# Updated with one Record (uuid: 5fc66dab-5e81-49ce-b439-8b12f8d24047) and Time taken --- 0.04796195030212402 seconds ---
# Average time taken for search = 0.07007420063018799
# Average time taken for conditional search = 0.6166716814041138
# =======================================================================================================
# For 30400000 entries, time taken for inserts = 124068.38893854522
# Updated with one Record (uuid: 30f90d73-6942-4787-bc84-27d9108b04dc) and Time taken --- 0.0458531379699707 seconds ---
# Average time taken for search = 0.0662766695022583
# Average time taken for conditional search = 0.4119671583175659
# =======================================================================================================
# For 30500000 entries, time taken for inserts = 124516.61101400756
# Updated with one Record (uuid: dd713266-8cf7-4134-848b-85e52fa67341) and Time taken --- 0.04810023307800293 seconds ---
# Average time taken for search = 0.05117189884185791
# Average time taken for conditional search = 0.6224972009658813
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/requests/models.py in json(self, **kwargs)
#     970         try:
# --> 971             return complexjson.loads(self.text, **kwargs)
#     972         except JSONDecodeError as e:
#
# /usr/lib/python3.10/json/__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     345             parse_constant is None and object_pairs_hook is None and not kw):
# --> 346         return _default_decoder.decode(s)
#     347     if cls is None:
#
# /usr/lib/python3.10/json/decoder.py in decode(self, s, _w)
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#
# /usr/lib/python3.10/json/decoder.py in raw_decode(self, s, idx)
#     354         except StopIteration as err:
# --> 355             raise JSONDecodeError("Expecting value", s, err.value) from None
#     356         return obj, end
#
# JSONDecodeError: Expecting value: line 2 column 1 (char 1)
#
# During handling of the above exception, another exception occurred:
#
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-105-5a5b0ad1ab75> in <cell line: 4>()
#       2 class_obj = initialize_class(client)
#       3 #download dataset and execute workload
# ----> 4 load_execute_workload(client, class_obj, dataset)
#
# <ipython-input-102-15bedb5c4e2d> in load_execute_workload(client, class_obj, dataset)
#      36       doc_embeddings.append(chunk['emb'][i])
#      37
# ---> 38     max_docs_loaded = upsert_db_measure(docs, doc_embeddings, client, chunk_size, max_docs_loaded, start_time, class_obj, previous_run_time)
#      39
#      40     # clear the lists because we want to re-use them for the next chunk
#
# <ipython-input-96-485380cf4019> in upsert_db_measure(docs, doc_embeddings, client, batch_size, total_inserted, workload_start_time, class_obj, previous_run_time)
#       9
#      10   # Configure a batch process, calls flush at the end of with block implicitly
# ---> 11   with client.batch as batch:
#      12     batch.batch_size=batch_size
#      13     start_time = time.time()
#
# /usr/local/lib/python3.10/dist-packages/weaviate/batch/crud_batch.py in __exit__(self, exc_type, exc_val, exc_tb)
#    1532
#    1533     def __exit__(self, exc_type, exc_val, exc_tb):
# -> 1534         self.flush()
#    1535         self.shutdown()
#    1536
#
# /usr/local/lib/python3.10/dist-packages/weaviate/batch/crud_batch.py in flush(self)
#    1150         if one is provided. (See the docs for `configure` or `__call__` for how to set one.)
#    1151         """
# -> 1152         self._send_batch_requests(force_wait=True)
#    1153
#    1154     def delete_objects(
#
# /usr/local/lib/python3.10/dist-packages/weaviate/batch/crud_batch.py in _send_batch_requests(self, force_wait)
#    1061         timeout_occurred = False
#    1062         for done_future in as_completed(self._future_pool):
# -> 1063             response_objects, nr_objects = done_future.result()
#    1064
#    1065             # handle objects response
#
# /usr/lib/python3.10/concurrent/futures/_base.py in result(self, timeout)
#     449                     raise CancelledError()
#     450                 elif self._state == FINISHED:
# --> 451                     return self.__get_result()
#     452
#     453                 self._condition.wait(timeout)
#
# /usr/lib/python3.10/concurrent/futures/_base.py in __get_result(self)
#     401         if self._exception:
#     402             try:
# --> 403                 raise self._exception
#     404             finally:
#     405                 # Break a reference cycle with the exception in self._exception
#
# <ipython-input-96-485380cf4019> in upsert_db_measure(docs, doc_embeddings, client, batch_size, total_inserted, workload_start_time, class_obj, previous_run_time)
#      20       }
#      21
# ---> 22       client.batch.add_data_object(properties, class_obj["class"], vector=doc_embeddings[i])
#      23
#      24   total_inserted += batch_size
#
# /usr/local/lib/python3.10/dist-packages/weaviate/batch/crud_batch.py in add_data_object(self, data_object, class_name, uuid, vector)
#     494
#     495         if self._batching_type:
# --> 496             self._auto_create()
#     497
#     498         return uuid
#
# /usr/local/lib/python3.10/dist-packages/weaviate/batch/crud_batch.py in _auto_create(self)
#    1133         if self._batching_type == "fixed":
#    1134             if sum(self.shape) >= self._batch_size:
# -> 1135                 self._send_batch_requests(force_wait=False)
#    1136             return
#    1137         elif self._batching_type == "dynamic":
#
# /usr/local/lib/python3.10/dist-packages/weaviate/batch/crud_batch.py in _send_batch_requests(self, force_wait)
#    1061         timeout_occurred = False
#    1062         for done_future in as_completed(self._future_pool):
# -> 1063             response_objects, nr_objects = done_future.result()
#    1064
#    1065             # handle objects response
#
# /usr/lib/python3.10/concurrent/futures/_base.py in result(self, timeout)
#     449                     raise CancelledError()
#     450                 elif self._state == FINISHED:
# --> 451                     return self.__get_result()
#     452
#     453                 self._condition.wait(timeout)
#
# /usr/lib/python3.10/concurrent/futures/_base.py in __get_result(self)
#     401         if self._exception:
#     402             try:
# --> 403                 raise self._exception
#     404             finally:
#     405                 # Break a reference cycle with the exception in self._exception
#
# /usr/lib/python3.10/concurrent/futures/thread.py in run(self)
#      56
#      57         try:
# ---> 58             result = self.fn(*self.args, **self.kwargs)
#      59         except BaseException as exc:
#      60             self.future.set_exception(exc)
#
# /usr/local/lib/python3.10/dist-packages/weaviate/batch/crud_batch.py in _flush_in_thread(self, data_type, batch_request)
#    1010
#    1011         if len(batch_request) != 0:
# -> 1012             response = self._create_data(
#    1013                 data_type=data_type,
#    1014                 batch_request=batch_request,
#
# /usr/local/lib/python3.10/dist-packages/weaviate/batch/crud_batch.py in _create_data(self, data_type, batch_request)
#     642                     connection_count += 1
#     643                 else:
# --> 644                     response_json = response.json()
#     645                     if (
#     646                         self._weaviate_error_retry is not None
#
# /usr/local/lib/python3.10/dist-packages/requests/models.py in json(self, **kwargs)
#     973             # Catch JSON-related errors and raise as requests.JSONDecodeError
#     974             # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
# --> 975             raise RequestsJSONDecodeError(e.msg, e.doc, e.pos)
#     976
#     977     @property
#
# JSONDecodeError: Expecting value: line 2 column 1 (char 1)
